# %% [markdown]
# # Wrangling Data

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy import stats
from scipy.stats import linregress
import numpy as np

# %%
# Import data files
income_data = "../data/med_income_state.csv"
food_table = "../data/food_table1.csv"

# Read the mouse data and the study results
income= pd.read_csv(income_data)
food_table = pd.read_csv(food_table)

# %%
food_table
# Out:
#                                            Food group  Total  At home  \
# 0                                                 NaN    NaN      NaN
# 1                                       Fruits (cups)    NaN      NaN
# 2                                   Total population1   1.05     0.94
# 3                                           Children2   1.08     0.90
# 4                                             Adults2   1.05     0.95
# ..                                                ...    ...      ...
# 89  2Children are those age 2-19 and adults are ag...    NaN      NaN
# 90                                                NaN    NaN      NaN
# 91  3The 185 percent income poverty line is the in...    NaN      NaN
# 92                                                NaN    NaN      NaN
# 93  Source: 2007-10 National Health and Nutrition ...    NaN      NaN
#
#    Away from home  Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0           Total  Restaurant  Fast food     School      Other
# 1             NaN         NaN        NaN        NaN        NaN
# 2            0.12        0.02       0.02       0.03       0.05
# 3            0.18        0.01       0.02        0.1       0.05
# 4             0.1        0.02       0.02          0       0.06
# ..            ...         ...        ...        ...        ...
# 89            NaN         NaN        NaN        NaN        NaN
# 90            NaN         NaN        NaN        NaN        NaN
# 91            NaN         NaN        NaN        NaN        NaN
# 92            NaN         NaN        NaN        NaN        NaN
# 93            NaN         NaN        NaN        NaN        NaN
#
# [94 rows x 8 columns]

# %%
income
# Out:
#                                                  State            2018  \
# 0                                                  NaN  Median\nincome
# 1                                        United States          63,179
# 2                                              Alabama          49,936
# 3                                               Alaska          68,734
# 4                                              Arizona          62,283
# ..                                                 ...             ...
# 105                                      West Virginia          50,573
# 106                                          Wisconsin          62,629
# 107                                            Wyoming          62,539
# 108  Source: U.S. Bureau of the Census, Current Pop...             NaN
# 109  Footnotes are available at <www.census.gov/top...             NaN
#
#           Unnamed: 2       2017 (40)       Unnamed: 4            2017  \
# 0    Standard\nerror  Median\nincome  Standard\nerror  Median\nincome
# 1                420          61,136              322          61,372
# 2              2,423          50,865            1,094          51,113
# 3              3,390          77,987            3,718          72,231
# 4              2,291          59,700            2,689          61,125
# ..               ...             ...              ...             ...
# 105            1,337          48,102            1,308          46,499
# 106            2,039          65,029            2,979          64,998
# 107            3,892          60,987            3,262          59,247
# 108              NaN             NaN              NaN             NaN
# 109              NaN             NaN              NaN             NaN
#
#           Unnamed: 6            2016       Unnamed: 8            2015  ...  \
# 0    Standard\nerror  Median\nincome  Standard\nerror  Median\nincome  ...
# 1                335          59,039              436          56,516  ...
# 2                845          47,221            2,301          44,509  ...
# 3              2,719          75,723            4,086          75,112  ...
# 4              2,642          57,100            1,971          52,248  ...
# ..               ...             ...              ...             ...  ...
# 105            1,521          46,412            2,087          45,389  ...
# 106            3,763          62,593            1,931          58,745  ...
# 107            3,210          60,513            3,267          64,575  ...
# 108              NaN             NaN              NaN             NaN  ...
# 109              NaN             NaN              NaN             NaN  ...
#
#                1988      Unnamed: 66       1987 (21)      Unnamed: 68  \
# 0    Median\nincome  Standard\nerror  Median\nincome  Standard\nerror
# 1            27,225              139          26,061              127
# 2            19,948              912          19,734            1,147
# 3            33,103            1,183          33,233            1,497
# 4            26,435              843          26,749              892
# ..              ...              ...             ...              ...
# 105          39,606            1,903          36,486            1,650
# 106          60,525            2,001          55,913            2,990
# 107          54,066            2,241          58,502            3,092
# 108             NaN              NaN             NaN              NaN
# 109             NaN              NaN             NaN              NaN
#
#                1986      Unnamed: 70       1985 (20)      Unnamed: 72  \
# 0    Median\nincome  Standard\nerror  Median\nincome  Standard\nerror
# 1            24,897              129          23,618              128
# 2            19,132              885          18,333              760
# 3            31,356            1,017          34,782            1,089
# 4            25,500              718          23,877              744
# ..              ...              ...             ...              ...
# 105          36,111            1,985          35,670            1,848
# 106          57,970            1,761          51,879            2,591
# 107          51,673            1,893          49,279            2,341
# 108             NaN              NaN             NaN              NaN
# 109             NaN              NaN             NaN              NaN
#
#           1984 (19)      Unnamed: 74
# 0    Median\nincome  Standard\nerror
# 1            22,415              102
# 2            17,310              605
# 3            32,356            1,473
# 4            21,425              609
# ..              ...              ...
# 105          38,880            1,403
# 106          47,882            1,895
# 107          54,976            1,687
# 108             NaN              NaN
# 109             NaN              NaN
#
# [110 rows x 75 columns]
